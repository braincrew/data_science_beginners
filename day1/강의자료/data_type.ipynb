# %% [markdown]
# # 변수 (자료형)

# %% [markdown]
# ###정수형 (int)

# %%
a=5
b=2
type(a)
# Out:
# int

# %%
a+b
# Out:
# 7

# %%
a-b
# Out:
# 3

# %%
a*b
# Out:
# 10

# %%
a/b
# Out:
# 2.5

# %%
a//b
# Out:
# 2

# %%
a%b
# Out:
# 1

# %%
a**b
# Out:
# 25

# %% [markdown]
# ### 실수형 (float)

# %%
b=3.14
type(b)
# Out:
# float

# %% [markdown]
# 실수형도 정수형과 마찬가지로 사칙연산이 가능합니다

# %% [markdown]
# ### 문자열 (str)

# %%
c='데이터 분석'
d='시작'
type(c)
# Out:
# str

# %%
c+d
# Out:
# '데이터 분석시작'

# %%
c[0]
# Out:
# '데'

# %%
c[3]
# Out:
# ' '

# %%
c[1:5]
# Out:
# '이터 분'

# %%
c.split()
# Out:
# ['데이터', '분석']

# %% [markdown]
# ### 리스트 (list)

# %%
d=[1, 2, 3, 4, 5]
type(d)
# Out:
# list

# %%
d[0]
# Out:
# 1

# %%
d[1]
# Out:
# 2

# %%
d[1:4]
# Out:
# [2, 3, 4]

# %%
d[-1]
# Out:
# 5

# %%
d[0]=0
d
# Out:
# [0, 2, 3, 4, 5]

# %%
d+[6, 7, 8]
# Out:
# [0, 2, 3, 4, 5, 6, 7, 8]

# %%
d.append(9)
d
# Out:
# [0, 2, 3, 4, 5, 9]

# %% [markdown]
# ### 딕셔너리 (dict)

# %%
e={'가':1, '나':2, '다':[3,4,5]}
type(e)
# Out:
# dict

# %%
e['가']
# Out:
# 1

# %%
e['다']
# Out:
# [3, 4, 5]

# %%
e['나']=6
e
# Out:
# {'가': 1, '나': 6, '다': [3, 4, 5]}

# %%
e['라']=7
e
# Out:
# {'가': 1, '나': 6, '다': [3, 4, 5], '라': 7}

# %% [markdown]
# ## 판다스의 자료형

# %% [markdown]
# ### 시리즈(series)

# %%
import pandas as pd

# %%
se=pd.Series([10, 20, 30, 40, 50])
se
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
type(se)
# Out:
# pandas.core.series.Series

# %% [markdown]
# ### 데이터프레임 (dataframe)

# %%
df=pd.DataFrame({"가":[11,12,13,14,15],
                "나":[21,22,23,24,25],
                "다":[31,32,33,34,35]})

# %%
df
# Out:
#     가   나   다
# 0  11  21  31
# 1  12  22  32
# 2  13  23  33
# 3  14  24  34
# 4  15  25  35

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame
