# %% [markdown]
# ## [과제 1]
#
# ### 다음과 같이 변수를 생성하였습니다.
# ### 다음 문제를 풀어주세요.

# %%
rep1 = 11
rep2 = 3
rep3 = "서울시 부동산 매매추이"
rep4 = [2,4,7,8,10]
rep5 = {"grape":"포도", "melon":"메론", "apple":"사과", "banana":"오렌지"}

# %% [markdown]
# ####1) 변수 rep5의 형태를 확인해주세요.

# %%
type(rep5)
# Out:
# dict

# %% [markdown]
# ####2) 변수 rep1을 변수 rep2로 나누었을 때 몫과 나머지를 구해주세요.

# %%
rep1 // rep2
# Out:
# 3

# %%
rep1 % rep2
# Out:
# 2

# %% [markdown]
# ####3) 변수 rep3를 띄어쓰기를 기준으로 분리해서 리스트로 만들어주세요.

# %%
rep3.split()
# Out:
# ['서울시', '부동산', '매매추이']

# %% [markdown]
# ####4) 리스트 rep4의 3번째 값인 7을 6으로 수정해주세요

# %%
rep4[2]=6
rep4
# Out:
# [2, 4, 6, 8, 10]

# %% [markdown]
# ####5) 딕셔너리 rep5에서 banana의 값을 바나나로 수정하고, orange를 추가해주세요.

# %%
rep5["banana"]="바나나"
rep5["orange"]="오렌지"
rep5
# Out:
# {'apple': '사과', 'banana': '바나나', 'grape': '포도', 'melon': '메론', 'orange': '오렌지'}

# %% [markdown]
# ##파일 불러오기

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3b213ede-56db-49b0-8e80-345d67740b2f" name="files[]" multiple disabled />
#      <output id="result-3b213ede-56db-49b0-8e80-345d67740b2f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-127-21dc3c638f66> in <module>()
#       1 from google.colab import files
# ----> 2 uploaded = files.upload()
#
# /usr/local/lib/python3.6/dist-packages/google/colab/files.py in upload()
#      62   result = _output.eval_js(
#      63       'google.colab._files._uploadFiles("{input_id}", "{output_id}")'.format(
# ---> 64           input_id=input_id, output_id=output_id))
# ...

# %%
import pandas as pd
import io

df = pd.read_csv(io.StringIO(uploaded['apart_dealing.csv'].decode('cp949')))
df
# Out:
#                  시군구       번지   본번  부번  ... 거래금액(만원)   층  건축년도       도로명
# 0      서울특별시 강남구 개포동    655-2  655   2  ...  134,500   4  1988       언주로
# 1      서울특별시 강남구 개포동    658-1  658   1  ...  160,000   4  1987       언주로
# 2      서울특별시 강남구 개포동    658-1  658   1  ...  160,000   5  1987       언주로
# 3      서울특별시 강남구 개포동    658-1  658   1  ...  124,000   4  1987       언주로
# 4      서울특별시 강남구 개포동    658-1  658   1  ...  141,000   5  1987       언주로
# 5      서울특별시 강남구 개포동      652  652   0  ...  170,000  10  1984       개포로
# 6      서울특별시 강남구 개포동      652  652   0  ...  165,000  12  1984       개포로
# 7      서울특별시 강남구 개포동      652  652   0  ...  240,000  15  1984       개포로
# 8      서울특별시 강남구 개포동      652  652   0  ...  197,000  12  1984       개포로
# 9      서울특별시 강남구 개포동      652  652   0  ...  157,000   6  1984       개포로
# 10     서울특별시 강남구 개포동  12월 02일   12   2  ...  175,000   8  2004   개포로109길
# 11     서울특별시 강남구 개포동  12월 02일   12   2  ...  200,000  12  2004   개포로109길
# ...

# %% [markdown]
# ## [과제 3]
#
# ### 단지명, 전용면적, 거래금액 컬럼만 보여주세요

# %%
df[["단지명","전용면적(㎡)","거래금액(만원)"]].head(10)
# Out:
#               단지명  전용면적(㎡) 거래금액(만원)
# 0  개포2차현대아파트(220)    77.75  134,500
# 1  개포6차우성아파트1동~8동    79.97  160,000
# 2  개포6차우성아파트1동~8동    79.97  160,000
# 3  개포6차우성아파트1동~8동    67.28  124,000
# 4  개포6차우성아파트1동~8동    79.97  141,000
# 5          개포우성3차   104.43  170,000
# 6          개포우성3차   104.43  165,000
# 7          개포우성3차   161.00  240,000
# 8          개포우성3차   133.46  197,000
# 9          개포우성3차   104.43  157,000

# %% [markdown]
# ##[과제 4]
# ### 아래와 같은 조건에 따라 '규모' 이라는 새로운 컬럼을 만들어 주세요.
# #### 전용면적 60㎡이하 - 소형
# #### 전용면적 60㎡초과 85㎡이하 - 중형
# #### 전용면적 85㎡초과 102㎡이하 - 중대형
# #### 전용면적 102㎡초과 - 대형

# %%
df.loc[df["전용면적(㎡)"]<=60, '규모']="소형"
df.loc[(df["전용면적(㎡)"]>60) & (df["전용면적(㎡)"]<=85), '규모']="중형"
df.loc[(df["전용면적(㎡)"]>85) & (df["전용면적(㎡)"]<=102), '규모']="중대형"
df.loc[df["전용면적(㎡)"]>102, '규모']="대형"
df.head()
# Out:
#              시군구     번지   본번  부번             단지명  ...  거래금액(만원)  층  건축년도  도로명  규모
# 0  서울특별시 강남구 개포동  655-2  655   2  개포2차현대아파트(220)  ...   134,500  4  1988  언주로  중형
# 1  서울특별시 강남구 개포동  658-1  658   1  개포6차우성아파트1동~8동  ...   160,000  4  1987  언주로  중형
# 2  서울특별시 강남구 개포동  658-1  658   1  개포6차우성아파트1동~8동  ...   160,000  5  1987  언주로  중형
# 3  서울특별시 강남구 개포동  658-1  658   1  개포6차우성아파트1동~8동  ...   124,000  4  1987  언주로  중형
# 4  서울특별시 강남구 개포동  658-1  658   1  개포6차우성아파트1동~8동  ...   141,000  5  1987  언주로  중형
#
# [5 rows x 13 columns]

# %% [markdown]
# ##[과제 5]
# ### 1) '계약년월' 컬럼의 데이터와 '계약일' 컬럼의 데이터를 합쳐서 '계약일' 컬럼으로 만들고, 날짜 타입으로 변환해주세요.

# %%
df["계약일"]=df["계약년월"].astype('str') + df["계약일"].astype('str')
df['계약일'] = pd.to_datetime(df['계약일'], format='%Y%m%d')
df.head()
# Out:
#              시군구     번지   본번  부번             단지명  ...  거래금액(만원)  층  건축년도  도로명  규모
# 0  서울특별시 강남구 개포동  655-2  655   2  개포2차현대아파트(220)  ...   134,500  4  1988  언주로  중형
# 1  서울특별시 강남구 개포동  658-1  658   1  개포6차우성아파트1동~8동  ...   160,000  4  1987  언주로  중형
# 2  서울특별시 강남구 개포동  658-1  658   1  개포6차우성아파트1동~8동  ...   160,000  5  1987  언주로  중형
# 3  서울특별시 강남구 개포동  658-1  658   1  개포6차우성아파트1동~8동  ...   124,000  4  1987  언주로  중형
# 4  서울특별시 강남구 개포동  658-1  658   1  개포6차우성아파트1동~8동  ...   141,000  5  1987  언주로  중형
#
# [5 rows x 13 columns]

# %% [markdown]
# ### 2) 계약일 기준으로 내림차순으로 정렬해주세요.

# %%
df.sort_values("계약일", ascending=False).head()
# Out:
#                  시군구    번지    본번  부번  ...   층  건축년도      도로명  규모
# 44116  서울특별시 양천구 신정동  1323  1323   0  ...   5  2016   중앙로36길  중형
# 19065  서울특별시 노원구 상계동  1255  1255   0  ...  12  1998  동일로245길  소형
# 22216  서울특별시 도봉구 도봉동   641   641   0  ...  17  1996      마들로  소형
# 22387  서울특별시 도봉구 도봉동   657   657   0  ...  12  2010      마들로  대형
# 36118  서울특별시 성북구 돈암동   524   524   0  ...   5  2005     아리랑로  대형
#
# [5 rows x 13 columns]

# %% [markdown]
# ##[과제 6]
# #### 1) '거래금액(만원)' 컬럼을 float 형태로 변환해주세요.
# ##### 힌트) 쉼표를 없애주어야 변환이 가능합니다.

# %%
df['거래금액(만원)'] = df['거래금액(만원)'].apply(lambda e: e.split(",")[0]+e.split(",")[1])
df['거래금액(만원)'] = df['거래금액(만원)'].convert_objects(convert_numeric=True)
df
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: FutureWarning: convert_objects is deprecated.  To re-infer data dtypes for object columns, use Series.infer_objects()
# For all other conversions use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#                  시군구       번지   본번  부번  ...   층  건축년도       도로명  규모
# 0      서울특별시 강남구 개포동    655-2  655   2  ...   4  1988       언주로  중형
# 1      서울특별시 강남구 개포동    658-1  658   1  ...   4  1987       언주로  중형
# 2      서울특별시 강남구 개포동    658-1  658   1  ...   5  1987       언주로  중형
# 3      서울특별시 강남구 개포동    658-1  658   1  ...   4  1987       언주로  중형
# 4      서울특별시 강남구 개포동    658-1  658   1  ...   5  1987       언주로  중형
# 5      서울특별시 강남구 개포동      652  652   0  ...  10  1984       개포로  대형
# 6      서울특별시 강남구 개포동      652  652   0  ...  12  1984       개포로  대형
# 7      서울특별시 강남구 개포동      652  652   0  ...  15  1984       개포로  대형
# ...

# %% [markdown]
# #### 2) '시군구' 컬럼의 데이터를 '시' 컬럼, '군'컬럼, '동'컬럼으로 분리해서 만들어 주세요

# %%
df['시']=df["시군구"].apply(lambda e: e.split()[0])
df['구']=df["시군구"].apply(lambda e: e.split()[1])
df['동']=df["시군구"].apply(lambda e: e.split()[2])
df.head()
# Out:
#              시군구     번지   본번  부번             단지명  ...  도로명  규모      시    구    동
# 0  서울특별시 강남구 개포동  655-2  655   2  개포2차현대아파트(220)  ...  언주로  중형  서울특별시  강남구  개포동
# 1  서울특별시 강남구 개포동  658-1  658   1  개포6차우성아파트1동~8동  ...  언주로  중형  서울특별시  강남구  개포동
# 2  서울특별시 강남구 개포동  658-1  658   1  개포6차우성아파트1동~8동  ...  언주로  중형  서울특별시  강남구  개포동
# 3  서울특별시 강남구 개포동  658-1  658   1  개포6차우성아파트1동~8동  ...  언주로  중형  서울특별시  강남구  개포동
# 4  서울특별시 강남구 개포동  658-1  658   1  개포6차우성아파트1동~8동  ...  언주로  중형  서울특별시  강남구  개포동
#
# [5 rows x 16 columns]

# %% [markdown]
# #### 3) 가락동의 중형아파트의 평균 거래금액은 얼마인가요?"

# %%
a=df[(df['동']=='가락동') & (df["규모"]=='중형')]
a['거래금액(만원)'].mean()
# Out:
# 83827.90697674418

# %% [markdown]
# #### 4) 5층이하인 등촌동의 중대형아파트의 단지명, 계약일, 거래금액 정보를 알려주세요.

# %%
b=df[(df['동']=='가락동') & (df["규모"]=='중형') & (df["층"]<=5)]
b[["단지명","계약일","거래금액(만원)"]]
# Out:
#                          단지명        계약일  거래금액(만원)
# 37979            가락(1차)쌍용아파트 2018-08-11     82000
# 37991            가락(1차)쌍용아파트 2018-08-20     79800
# 37997            가락(1차)쌍용아파트 2018-08-23     79900
# 38001            가락(1차)쌍용아파트 2018-08-25     81000
# 38013            가락(1차)쌍용아파트 2018-08-30     85000
# 38015            가락(1차)쌍용아파트 2018-08-31     86000
# 38022            가락(1차)쌍용아파트 2018-09-03     83500
# 38023            가락(1차)쌍용아파트 2018-09-03     85000
# 38025            가락(1차)쌍용아파트 2018-09-05     83000
# 38028            가락(1차)쌍용아파트 2018-09-10     89900
# 38060            가락(1차)쌍용아파트 2019-05-14     80600
# 38061            가락(1차)쌍용아파트 2019-05-21     80500
# 38068            가락(1차)쌍용아파트 2019-06-01     84800
# 38079            가락(1차)쌍용아파트 2019-06-21     85700
# 38094            가락(1차)쌍용아파트 2019-07-08     81000
# 38095            가락(1차)쌍용아파트 2019-07-09     87500
# 38097            가락(1차)쌍용아파트 2019-07-12     87500
# 38105  가락3차쌍용스윗닷홈 101동, 102동 2019-02-12     82000
# ...
